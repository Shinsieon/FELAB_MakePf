# %%
from pykrx import stock 
import pandas as pd
import numpy as np

# %%
df = stock.get_market_ohlcv("20130101", "20220810", "005930","m")
dfIndex = df.index
dfIndex
# Out:
# DatetimeIndex(['2013-01-31', '2013-02-28', '2013-03-31', '2013-04-30',
#                '2013-05-31', '2013-06-30', '2013-07-31', '2013-08-31',
#                '2013-09-30', '2013-10-31',
#                ...
#                '2021-11-30', '2021-12-31', '2022-01-31', '2022-02-28',
#                '2022-03-31', '2022-04-30', '2022-05-31', '2022-06-30',
#                '2022-07-31', '2022-08-31'],
#               dtype='datetime64[ns]', name='날짜', length=116, freq='M')

# %%
df2 = stock.get_market_ohlcv("20140101", "20220810", "100250","m")
df2
# Out:
#               시가    고가    저가    종가       거래량
# 날짜
# 2014-01-31  1970  2110  1890  2090   2402606
# 2014-02-28  2090  2745  2075  2700  10154176
# 2014-03-31  2660  3645  2490  3155  12186445
# 2014-04-30  3190  3520  2955  3270  12995971
# 2014-05-31  3270  3895  3160  3250  15486825
# ...          ...   ...   ...   ...       ...
# 2022-04-30  3795  3885  3635  3740   2701809
# 2022-05-31  3740  3935  3370  3880   3038868
# 2022-06-30  3900  4155  3640  3655   5175174
# 2022-07-31  3640  3700  3430  3585    948599
# 2022-08-31  3585  3605  3545  3560    362241
#
# [104 rows x 5 columns]

# %%
df2['종가'].pct_change().fillna(0).values
# Out:
# array([ 0.        ,  0.29186603,  0.16851852,  0.03645008, -0.00611621,
#        -0.02769231,  0.09177215,  0.01304348,  0.53361946, -0.10261194,
#        -0.06237006, -0.0886918 ,  0.00486618, -0.01937046,  0.0962963 ,
#         0.0259009 ,  0.00329308, -0.07439825, -0.06737589, -0.00760456,
#        -0.00510856,  0.05134788, -0.09401709, -0.00269542, -0.14324324,
#         0.03312303,  0.17099237, -0.07301173, -0.05907173,  0.06726457,
#         0.02941176, -0.02312925, -0.01671309, -0.01558074, -0.05179856,
#         0.01669196, -0.06119403,  0.04133545, -0.0259542 ,  0.02821317,
#         0.03506098, -0.01325479, -0.04626866, -0.00625978,  0.        ,
#        -0.02047244, -0.01768489, -0.01800327, -0.00333333, -0.05685619,
#        -0.02659574,  0.03278689, -0.02116402, -0.01441441, -0.04936015,
#         0.04615385,  0.01838235, -0.20216606,  0.17647059,  0.03653846,
#         0.00556586, -0.04612546, -0.01547389,  0.00196464,  0.00588235,
# ...

# %%
df['종가'].pct_change()
# Out:
# 날짜
# 2013-01-31         NaN
# 2013-02-28    0.066298
# 2013-03-31   -0.011010
# 2013-04-30   -0.004584
# 2013-05-31    0.011842
#                 ...
# 2022-04-30   -0.031609
# 2022-05-31    0.000000
# 2022-06-30   -0.154303
# 2022-07-31    0.077193
# 2022-08-31   -0.037459
# Freq: M, Name: 종가, Length: 116, dtype: float64

# %%
newDf = pd.concat([df2['종가'].pct_change(),df['종가'].pct_change()], axis=1)
newDf.fillna(0)
# Out:
#                   종가        종가
# 날짜
# 2013-01-31  0.000000  0.000000
# 2013-02-28  0.000000  0.066298
# 2013-03-31  0.000000 -0.011010
# 2013-04-30  0.000000 -0.004584
# 2013-05-31  0.000000  0.011842
# ...              ...       ...
# 2022-04-30 -0.015789 -0.031609
# 2022-05-31  0.037433  0.000000
# 2022-06-30 -0.057990 -0.154303
# 2022-07-31 -0.019152  0.077193
# 2022-08-31 -0.006974 -0.037459
#
# [116 rows x 2 columns]

# %%
df.index
# Out:
# DatetimeIndex(['2015-07-31', '2015-08-31', '2015-09-30', '2015-10-31',
#                '2015-11-30', '2015-12-31', '2016-01-31', '2016-02-29',
#                '2016-03-31', '2016-04-30', '2016-05-31', '2016-06-30',
#                '2016-07-31', '2016-08-31', '2016-09-30', '2016-10-31',
#                '2016-11-30', '2016-12-31', '2017-01-31', '2017-02-28',
#                '2017-03-31', '2017-04-30', '2017-05-31', '2017-06-30',
#                '2017-07-31', '2017-08-31', '2017-09-30', '2017-10-31',
#                '2017-11-30', '2017-12-31', '2018-01-31', '2018-02-28',
#                '2018-03-31', '2018-04-30', '2018-05-31', '2018-06-30',
#                '2018-07-31', '2018-08-31', '2018-09-30', '2018-10-31',
#                '2018-11-30', '2018-12-31', '2019-01-31', '2019-02-28',
#                '2019-03-31', '2019-04-30', '2019-05-31', '2019-06-30',
#                '2019-07-31', '2019-08-31', '2019-09-30', '2019-10-31',
# ...

# %%
from datetime import datetime
today = datetime.today().strftime("%Y%m%d")
tickers = stock.get_market_ticker_list()
tickers
# Out:
# ['095570',
#  '006840',
#  '027410',
#  '282330',
#  '138930',
#  '001460',
#  '001465',
#  '001040',
#  '079160',
#  '00104K',
#  '000120',
#  '011150',
#  '011155',
#  '001045',
#  '097950',
#  '097955',
#  '000590',
#  '012030',
#  '016610',
#  '005830',
#  '000990',
#  '000995',
#  '139130',
#  '001530',
#  '000210',
#  '001880',
#  '000215',
#  '375500',
#  '37550L',
#  '37550K',
#  '007340',
#  '004840',
#  '155660',
#  '069730',
#  '017940',
#  '365550',
#  '383220',
#  '007700',
#  '114090',
#  '078930',
#  '006360',
#  '001250',
#  '007070',
#  '078935',
#  '012630',
#  '039570',
#  '089470',
#  '294870',
#  '267250',
#  '329180',
#  '097230',
#  '014790',
#  '003580',
#  '204320',
#  '060980',
#  '011200',
#  '082740',
#  '003560',
#  '175330',
#  '234080',
#  '001060',
#  '001067',
#  '001065',
#  '096760',
#  '105560',
#  '432320',
#  '002380',
#  '344820',
#  '009070',
#  '009440',
#  '119650',
#  '092220',
#  '003620',
#  '016380',
#  '001390',
#  '033180',
# ...

# %%
# student_card = pd.DataFrame({'ID':[20190103, 20190222, 20190531],
#                              'name':['Kim', 'Lee', 'Jeong'],
#                              'class':['H', 'W', 'S']}, index = ['a', 'b', 'c'])   #index 지정
obj = {}
for ticker in tickers :
    item = stock.get_market_ohlcv("20130101", "20220810", ticker,"m").pct_change().fillna(0)
    if len(item)>0:
        try:
            obj[ticker] = stock.get_market_ohlcv("20130101", "20220810", ticker,"m").pct_change().fillna(0)['종가'].values
        except : 
            continue

# %%
item = stock.get_market_ohlcv("20130101", "20220810", "005930","m").pct_change().fillna(0)['종가']
if(item):
    ("hi")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[40], line 2
#       1 item = stock.get_market_ohlcv("20130101", "20220810", "005930","m").pct_change().fillna(0)['종가']
# ----> 2 if(item):
#       3     ("hi")
#
# File ~/.pyenv/versions/venv/lib/python3.8/site-packages/pandas/core/generic.py:1527, in NDFrame.__nonzero__(self)
#    1525 @final
#    1526 def __nonzero__(self) -> NoReturn:
# -> 1527     raise ValueError(
#    1528         f"The truth value of a {type(self).__name__} is ambiguous. "
#    1529         "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#    1530     )
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
len(item)
# Out:
# 116
